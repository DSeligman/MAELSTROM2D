# %%
# %matplotlib inline
import pyamg
from numpy import *
# %matplotlib inline
from matplotlib.pyplot import *
def indices_ptoc(i,j,ny):
    ind = ny*i +j
    return( ind)
def indices_ctop(ind,ny):
    j=ind%ny
    i=(ind-j)/ny
    return(i,j)
def get_vort(vxo,vyo,nx,ny):
    vorto=zeros_like(vxo)
    for i in arange(1,nx-1):
        for j in arange(1,ny-1):
            vorto[i,j] =(vxo[i,j+1]-vxo[i,j-1])/(2.*dy)\
            -(vyo[i+1,j]-vyo[i-1,j])/(2.*dx)
    return vorto
def get_vort2(vxo,vyo,nx,ny,dx,dy):
    vorto=zeros_like(vxo)
    for i in arange(1,nx-1):
        for j in arange(1,ny-1):
            vorto[i,j] =(vxo[i,j+1]-vxo[i,j-1])/(2.*dy)\
            -(vyo[i+1,j]-vyo[i-1,j])/(2.*dx)
    return vorto
nx = 66
ny=66
i=0
cnt=0
extent = 1.
global dx
dx=extent/nx
#dx=1.                                                                           
global dy
dy=extent/ny

xl=zeros(nx)
yl=zeros(ny)

for i in arange(0,nx):
    if i<nx/2:
        xl[i]=-dx*(nx/2-1-i)
    if i>=nx/2:
        xl[i]=dx*(i+1-nx/2)

for i in arange(0,ny):
    if i<nx/2:
        yl[i]=-dx*(nx/2-1-i)
    if i>=nx/2:
        yl[i]=dx*(i+1-ny/2)
# Out:
# //anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
vx=loadtxt("outputs/ux.txt",delimiter=',',dtype='string')
vy=loadtxt("outputs/uy.txt",delimiter=',',dtype='string')
rho=loadtxt("outputs/rho.txt",delimiter=',',dtype='string')
En=loadtxt("outputs/E.txt",delimiter=',',dtype='string')

# %%
#nx = 64
#ny=64
vxo=zeros((nx,ny))
vyo=zeros((nx,ny))
dno=zeros((nx,ny),dtype='double')
E=zeros((nx,ny),dtype='double')

vxo0=zeros((nx,ny))
vyo0=zeros((nx,ny))
dno0=zeros((nx,ny),dtype='double')
E0=zeros((nx,ny),dtype='double')

ind1=103
for ind in arange(0,nx*ny):
    #dno[indices_ctop(ind,ny)]=density[150][ind]
    vxo[indices_ctop(ind,ny)]=vx[ind1][ind]
    vyo[indices_ctop(ind,ny)]=vy[ind1][ind]
    dno[indices_ctop(ind,ny)]=rho[ind1][ind]
    E[indices_ctop(ind,ny)]=En[ind1][ind]
    vxo0[indices_ctop(ind,ny)]=vx[0][ind]
    vyo0[indices_ctop(ind,ny)]=vy[0][ind]
    dno0[indices_ctop(ind,ny)]=rho[0][ind]
    E0[indices_ctop(ind,ny)]=En[0][ind]

# %%
plot(xl,vxo0.T[:,nx/2],'k',label='Initial')
plot(xl[::1],vxo.T[::1,nx/2],'bo',label = 'Evolved')
#plot(xl,dno0.T[:,nx/2],'k',label='Initial')
#plot(xl[::3],dno.T[::3,nx/2],'bo',label = 'Evolved')
legend()
xlabel('y')
ylabel('U')
#savefig("1dShear_U_64.pdf")

# %%
fig =figure()#plt.subplots()
ax = fig.add_axes([0.18, 0.12, 0.3, 0.85])
ax2 = fig.add_axes([0.5, 0.12, 0.4, 0.85])#,projection='3d')
#ax4 = fig.add_axes([0.10, 0.895, 0.87, 0.1])
#ax3 = fig.add_axes([0.10, 0.890, 0.87, 0.050],sharex=ax)
ax3=ax2.twinx()
ax4=fig.add_axes([0.12, 0.12, 0.05, 0.85])
ax4.set_ylabel('HELLO')
x, y = mgrid[0:ny:ny*1j, 0:nx:nx*1j]
im=ax.imshow(vxo[::,::].T,cmap='bone')
cat = 10
ax.set_xlim([17,43])
ax.quiver(x[30:40:cat,::2],y[30:40:cat,::2],vxo[30:40:cat,::2],vyo[30:40:cat,::2],vxo[30:40:cat,::2]
        ,scale=.2,cmap='bone_r',width=.03)#,headwidth=15,headlength=15,width=1)

#axis('equal')
ax.axis('off')
ax2.plot(-1*vxo0.T[:,nx/2],xl,color='grey',linewidth=3,label='Initial')
ax2.plot(-1.*vxo.T[::2,nx/2],xl[::2],'o',label = 'Evolved',color='purple',markersize=5)
ax2.legend(prop={'size': 9},loc='lower right',ncol=1,fancybox=True, shadow=True)
ax2.set_xlim([-.12,.12])
ax2.get_yaxis().set_ticks([])
ax3.set_ylabel('y')
ax2.set_xlabel('u(y)')
cbar= fig.colorbar(im,cax=ax4)#,##orientation='horizontal', cax=ax4)
ax.text(22, 15, "X-Velocity", ha="center", va="center", rotation=90,
            size=12)
#ax2.yaxis('off')

ax4.yaxis.set_ticks_position('left')
cbar.set_label('u(y)', rotation=90)
ax4.yaxis.set_label_position('left')
#ax6=ax4.twinx()
#ax6.set_ylabel('v')

savefig('ShearFlow.pdf')

# %%
#new fig with norm
fig =figure()#plt.subplots()


ax = fig.add_axes([0.13, 0.12, 0.3, 0.85])
ax2 = fig.add_axes([0.6, 0.12, 0.3, 0.85])#,projection='3d')
#ax4 = fig.add_axes([0.10, 0.895, 0.87, 0.1])
#ax3 = fig.add_axes([0.10, 0.890, 0.87, 0.050],sharex=ax)
ax3=ax2.twinx()
ax4=fig.add_axes([0.11, 0.12, 0.05, 0.85])
ax4.set_ylabel('HELLO')

ax5 = fig.add_axes([0.4, 0.12, 0.2, 0.85])
ax5.get_yaxis().set_ticks([])

x, y = mgrid[0:ny:ny*1j, 0:nx:nx*1j]
im=ax.imshow(vxo[::,::].T,cmap='bone')
cat = 10
ax.set_xlim([17,43])
ax.quiver(x[30:40:cat,::2],y[30:40:cat,::2],vxo[30:40:cat,::2],vyo[30:40:cat,::2],vxo[30:40:cat,::2]
        ,scale=.2,cmap='bone_r',width=.03)#,headwidth=15,headlength=15,width=1)

#axis('equal')
ax.axis('off')
ax2.plot(-1*vxo0.T[:,nx/2],xl,color='black',linewidth=.3,label='Initial')
ax2.plot(-1.*vxo.T[::2,nx/2],xl[::2],'x',label = 'Evolved',color='purple',markersize=5)
ax2.legend(prop={'size': 9},bbox_to_anchor=(.9, .4),ncol=1,fancybox=True, shadow=True)
ax5.plot(abs((vxo.T[::2,nx/2]-vxo0.T[::2,nx/2])/vxo0.T[::2,nx/2]),xl[::2],'*',label='y='+str(xl[5])[0:3],color='silver',markersize=6)

ax2.set_xlim([-.12,.12])
#ax2.set_ylim([.1,.9])
ax2.get_yaxis().set_ticks([])
ax3.set_ylabel('$y$',fontsize=13)

ax2.set_xlabel('u(y)')
cbar= fig.colorbar(im,cax=ax4)#,##orientation='horizontal', cax=ax4)
ax.text(22, 15, "X-Velocity", ha="center", va="center", rotation=90,
            size=12)
#ax2.yaxis('off')

ax4.yaxis.set_ticks_position('left')
#cbar.set_label('u(y)', rotation=90)
cbar.set_label('$u(x,y)$',fontsize=13, rotation=90,labelpad=.01)
ax4.yaxis.set_label_position('left')
#ax6=ax4.twinx()
#ax6.set_ylabel('v')
ax5.set_xlim([-1.4e-2,1.4e-2])
ax5.set_xticks([-1e-2, 0.,1e-2])
ax2.set_xticks([-.08,0.0,.08])
ax2.set_xlabel('$u(x)$',fontsize=13)
ax5.set_xlabel('$|u-u_0|/u_0$',fontsize=13)
savefig('ShearFlowL2norm.pdf')

# %%
#now for the Hydrostatic Equilibrium Case
vx=loadtxt("output_HydroEq/ux.txt",delimiter=',',dtype='string')
vy=loadtxt("output_HydroEq/uy.txt",delimiter=',',dtype='string')
rho=loadtxt("output_HydroEq/rho.txt",delimiter=',',dtype='string')
En=loadtxt("output_HydroEq/E.txt",delimiter=',',dtype='string')

# %%
#nx = 64
#ny=64
vxo=zeros((nx,ny))
vyo=zeros((nx,ny))
dno=zeros((nx,ny),dtype='double')
E=zeros((nx,ny),dtype='double')

vxo0=zeros((nx,ny))
vyo0=zeros((nx,ny))
dno0=zeros((nx,ny),dtype='double')
E0=zeros((nx,ny),dtype='double')

ind1=18
for ind in arange(0,nx*ny):
    #dno[indices_ctop(ind,ny)]=density[150][ind]
    vxo[indices_ctop(ind,ny)]=vx[ind1][ind]
    vyo[indices_ctop(ind,ny)]=vy[ind1][ind]
    dno[indices_ctop(ind,ny)]=rho[ind1][ind]
    E[indices_ctop(ind,ny)]=En[ind1][ind]
    vxo0[indices_ctop(ind,ny)]=vx[0][ind]
    vyo0[indices_ctop(ind,ny)]=vy[0][ind]
    dno0[indices_ctop(ind,ny)]=rho[0][ind]
    E0[indices_ctop(ind,ny)]=En[0][ind]

# %%
figure(1)
imshow(dno.T)#,vmin=.99999,vmax=1.00001)
colorbar()
figure(2)
imshow(dno0.T)
colorbar()
figure(3)
imshow(vxo.T)#,vmin=.99999,vmax=1.00001)
colorbar()
figure(4)
imshow(vxo0.T)
colorbar()

# %%
plot(xl,vxo0.T[:,nx/2],'k',label='Initial')
plot(xl[::1],vxo.T[::1,nx/2],'bo',label = 'Evolved')
#plot(xl,dno0.T[:,nx/2],'k',label='Initial')
#plot(xl[::3],dno.T[::3,nx/2],'bo',label = 'Evolved')
legend()
xlabel('y')
ylabel('U')

# %%
plot(xl,vyo0.T[:,nx/2],'k',label='Initial')
plot(xl[::1],vyo.T[::1,nx/2],'bo',label = 'Evolved')
#plot(xl,dno0.T[:,nx/2],'k',label='Initial')
#plot(xl[::3],dno.T[::3,nx/2],'bo',label = 'Evolved')
legend()
xlabel('y')
ylabel('V')

# %%
#now set up the evolution plots
alpha1=.1
for ind1 in arange(0,19,3):

    for ind in arange(0,nx*ny):
    #dno[indices_ctop(ind,ny)]=density[150][ind]
        vxo[indices_ctop(ind,ny)]=vx[ind1][ind]
        
        dno[indices_ctop(ind,ny)]=rho[ind1][ind]
        
        vxo0[indices_ctop(ind,ny)]=vx[0][ind]
        
        dno0[indices_ctop(ind,ny)]=rho[0][ind]
    print "t"
    alpha1+=.1
    plot(xl[::1],vxo.T[::1,nx/2],'k',label = 'Evolved',alpha=alpha1)
    
xlabel('y')
ylabel('U')
savefig("1dShear_HydroEq_U.pdf")
# Out:
# t
# t
# t
# t
# t
# t
# t

# %%
ind1=10
for ind in arange(0,nx*ny):
    vxo[indices_ctop(ind,ny)]=vx[ind1][ind]
    dno[indices_ctop(ind,ny)]=rho[ind1][ind]
    vxo0[indices_ctop(ind,ny)]=vx[0][ind]
    dno0[indices_ctop(ind,ny)]=rho[0][ind]
fig =figure()#plt.subplots()
ax = fig.add_axes([0.18, 0.12, 0.3, 0.85])
ax2 = fig.add_axes([0.5, 0.12, 0.4, 0.85])#,projection='3d')
#ax4 = fig.add_axes([0.10, 0.895, 0.87, 0.1])
#ax3 = fig.add_axes([0.10, 0.890, 0.87, 0.050],sharex=ax)
ax3=ax2.twinx()
ax4=fig.add_axes([0.12, 0.12, 0.05, 0.85])

x, y = mgrid[0:ny:ny*1j, 0:nx:nx*1j]
im=ax.imshow(log(dno[::,::]).T,cmap='bone_r',origin='lower left')
cat = 10
ax.set_xlim([17,43])
stride=15
fin=65
fin1=10
ax.quiver(x[24:32:cat,fin1:fin:stride],y[24:32:cat,fin1:fin:stride],zeros_like(dno[30:40:cat,fin1:fin:stride]),
          -1.*dno[30:40:cat,fin1:fin:stride],-1.*vxo0[30:40:cat,fin1:fin:stride]
        ,scale=2.0,cmap='bone_r',width=.03,pivot='mid')#
ax.quiver(x[37:50:cat,fin1:fin:stride],y[37:50:cat,fin1:fin:stride],zeros_like(dno[30:40:cat,fin1:fin:stride]),
          1.*dno[30:40:cat,fin1:fin:stride],vxo0[30:40:cat,fin1:fin:stride]
        ,scale=2.0,cmap='bone',width=.03,pivot='mid',headlength=5,headwidth=3)#

ax.text(20, 50, "Gravity", ha="center", va="center", rotation=90,
            size=12)
ax.text(41, 50, "Pressure", ha="center", va="center", rotation=90,
            size=12)
            #bbox=bbox_props)

#axis('equal')
ax.axis('off')
ax2.plot(log(dno0).T[:,nx/2],xl,color='grey',linewidth=3,label='Initial')
ax2.plot(log(dno).T[3:nx-1:2,nx/2],xl[3:nx-1:2],'o',label = 'Evolved',color='purple',markersize=5)
ax2.legend(prop={'size': 9},loc='upper right',ncol=1,fancybox=True, shadow=True)
ax2.set_xlim([-1.19,.11])
#ax2.set_ylim([-0.0,1.0])
ax2.get_yaxis().set_ticks([])
ax3.set_ylabel('y')
ax2.set_xlabel(r'ln($\rho/\rho_0$)(y)',)
cbar= fig.colorbar(im,cax=ax4)#,##orientation='horizontal', cax=ax4)

#ax2.yaxis('off')

ax4.yaxis.set_ticks_position('left')
cbar.set_label(r'ln($\rho/\rho_0$)(y)', rotation=90)
ax4.yaxis.set_label_position('left')
savefig('ShearFlowHydro.pdf')

# %%
#now set up the evolution plots
alpha1=.1
for ind1 in arange(0,19,3):

    for ind in arange(0,nx*ny):
    #dno[indices_ctop(ind,ny)]=density[150][ind]
        vxo[indices_ctop(ind,ny)]=vx[ind1][ind]
        
        dno[indices_ctop(ind,ny)]=rho[ind1][ind]
        
        vxo0[indices_ctop(ind,ny)]=vx[0][ind]
        
        dno0[indices_ctop(ind,ny)]=rho[0][ind]
    
    alpha1+=.1
    plot(xl[::1],dno.T[::1,nx/2],'k',label = 'Evolved',alpha=alpha1)
    
xlabel('y')
ylabel('rho')
savefig("1dShear_HydroEq_rho.pdf")

# %%
#set up the hydrostatic equilibrium
extent = 1.
dx=1./64.
dy= 1./64.
dn = dno0.T[::1,nx/2]
#plot(dn)
print dn.shape
print dn[0:10]

print dn[1]
print (dn[0]-dn[2])/(2.*dx)
rho_num = np.zeros_like(dn)

rho_num[0]=dn[0]
print dn[0]
print dn[2]
rho_num[1]=dn[1]
for i in arange(2,len(dn)):
    rho_num[i]=-1.*1.*2.*dx*dn[i-1]+dn[i-2]
#plot(rho_num,'bo')

plot(dn)
# Out:
# (66,)
# [ 1.        0.984536  0.969233  0.954248  0.939413  0.924891  0.91051
#   0.896438  0.882496  0.86886 ]
# 0.984536
# 0.984544
# 1.0
# 0.969233

# %%
#construct the numerical solution

rho_num = np.zeros_like(dn)
rho_num[0]=1.
rho_num[2] = np.exp(-2.*dx)


rho_num[1]=(rho_num[0]-rho_num[2])/(2.*dy)
for i in arange(3,len(dn)):
    rho_num[i]=-1.*1.*2.*dx*rho_num[i-1]+rho_num[i-2]
#plot(rho_num[0:])
#plot(dn)
plot(dn/rho_num)
print rho_num[1]
print np.exp(-2.*dx)

print rho_num[2]
print rho_num[3]


print (-rho_num[2]+rho_num[0])/(2.*dx)
print rho_num[1]

print (-dn[2]+dn[0])/(2.*dx)
print dn[1]
print dx
print rho_num
# Out:
# 0.984536496757
# 0.969233234476
# 0.969233234476
# 0.95424795818
# 0.984536496757
# 0.984536496757
# 0.984544
# 0.984536
# 0.015625
# [ 1.          0.9845365   0.96923323  0.95424796  0.93941299  0.9248913
#   0.91051013  0.89643786  0.88249645  0.86885985  0.85534458  0.84213033
#   0.82902801  0.8162232   0.80352103  0.79111317  0.77879874  0.76677571
#   0.754837    0.74318705  0.73161241  0.72032417  0.70910228  0.69816472
#   0.68728463  0.67668708  0.66613816  0.65587026  0.64564221  0.63569394
#   0.62577678  0.61613841  0.60652245  0.59718459  0.58786043  0.57881395
#   0.5697725   0.56100856  0.55224098  0.54375103  0.53524876  0.5270245
#   0.51877925  0.51081265  0.50281635  0.49509964  0.48734449  0.47987013
#   0.47234855  0.46510923  0.45781388  0.45080255  0.4437263   0.4369361
#   0.43007205  0.42349635  0.41683779  0.41047017  0.40401059  0.39784484
#   0.39157794  0.38560803  0.37952769  0.37374779  0.36784807  0.36225254]

# %%
#plot(dn)
#plot(dno0.T[::1,nx/2])
plot(dn/dno0.T[::1,nx/2])
